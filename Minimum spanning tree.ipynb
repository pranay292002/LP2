# %%
import copy

final = [[1, 2, 3], [4, 5, 6], [7, 8, -1]]
initial = [[1, 2, 3], [-1, 4, 6], [7, 5, 8]]


def gn(state, finalstate):
    count = 0
    for i in range(3):
        for j in range(3):
            if state[i][j] != -1:
                if state[i][j] != finalstate[i][j]:
                    count += 1
    return count


def findposofblank(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == -1:
                return [i, j]


def move_left(state, pos):
    if pos[1] == 0:
        return None
    retarr = copy.deepcopy(state)
    retarr[pos[0]][pos[1]], retarr[pos[0]][pos[1] - 1] = retarr[pos[0]][pos[1] - 1], retarr[pos[0]][pos[1]]
    return retarr


def move_up(state, pos):
    if pos[0] == 0:
        return None
    retarr = copy.deepcopy(state)
    retarr[pos[0]][pos[1]], retarr[pos[0] - 1][pos[1]] = retarr[pos[0] - 1][pos[1]], retarr[pos[0]][pos[1]]
    return retarr


def move_right(state, pos):
    if pos[1] == 2:
        return None
    retarr = copy.deepcopy(state)
    retarr[pos[0]][pos[1]], retarr[pos[0]][pos[1] + 1] = retarr[pos[0]][pos[1] + 1], retarr[pos[0]][pos[1]]
    return retarr


def move_down(state, pos):
    if pos[0] == 2:
        return None
    retarr = copy.deepcopy(state)
    retarr[pos[0]][pos[1]], retarr[pos[0] + 1][pos[1]] = retarr[pos[0] + 1][pos[1]], retarr[pos[0]][pos[1]]
    return retarr


def printMatrix(matricesArray):
    print("")
    counter = 1
    for matrix in matricesArray:
        print("Step {}".format(counter))
        for row in matrix:
            print(row)
        counter += 1
        print("")


def eightPuzzle(initialstate, finalstate):
    hn = 0
    explored = []
    while True:
        explored.append(initialstate)
        if initialstate == finalstate:
            break
        hn += 1
        left = move_left(initialstate, findposofblank(initialstate))
        right = move_right(initialstate, findposofblank(initialstate))
        up = move_up(initialstate, findposofblank(initialstate))
        down = move_down(initialstate, findposofblank(initialstate))
        fnl = 1000
        fnr = 1000
        fnu = 1000
        fnd = 1000
        if left is not None:
            fnl = hn + gn(left, finalstate)
        if right is not None:
            fnr = hn + gn(right, finalstate)
        if up is not None:
            fnu = hn + gn(up, finalstate)
        if down is not None:
            fnd = hn + gn(down, finalstate)
        minfn = min(fnl, fnr, fnu, fnd)
        if (fnl == minfn) and (left not in explored):
            initialstate = left
        elif (fnr == minfn) and (right not in explored):
            initialstate = right
        elif (fnu == minfn) and (up not in explored):
            initialstate = up
        elif (fnd == minfn) and (down not in explored):
            initialstate = down
    printMatrix(explored)


def main():
    while True:
        ch = int(input("PRESS 1 to continue and 0 to Exit: "))
        if not ch:
            break
        start = []
        print("START STATE\n")
        for i in range(3):
            arr = []
            for j in range(3):
                a = int(input("Enter element at  {},{}: ".format(i, j)))
                arr.append(a)
            start.append(arr)
        final_state = []
        print("FINAL STATE\n")
        for i in range(3):
            arr = []
            for j in range(3):
                a = int(input("Enter element at  {},{}: ".format(i, j)))
                arr.append(a)
            final_state.append(arr)
        eightPuzzle(start, final_state)


main()
# Out:
# PRESS 1 to continue and 0 to Exit: 1
# START STATE
#
# Enter element at  0,0: 2
# Enter element at  0,1: 3
# Enter element at  0,2: 2
# Enter element at  1,0: 4
# Enter element at  1,1: 3
# Enter element at  1,2: 2
# Enter element at  2,0: 3
# Enter element at  2,1: 2
# Enter element at  2,2: 4
# FINAL STATE
#
# Enter element at  0,0: 6
# Enter element at  0,1: 7
# Enter element at  0,2: 6
# Enter element at  1,0: 4
# Enter element at  1,1: 1
# Enter element at  1,2: 6
# Enter element at  2,0: 5
# Enter element at  2,1: 3
# Enter element at  2,2: 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 127
#     123             final_state.append(arr)
#     124         eightPuzzle(start, final_state)
# --> 127 main()
#
# Cell In[1], line 124, in main()
#     122         arr.append(a)
#     123     final_state.append(arr)
# --> 124 eightPuzzle(start, final_state)
#
# Cell In[1], line 75, in eightPuzzle(initialstate, finalstate)
#      73     break
#      74 hn += 1
# ---> 75 left = move_left(initialstate, findposofblank(initialstate))
#      76 right = move_right(initialstate, findposofblank(initialstate))
#      77 up = move_up(initialstate, findposofblank(initialstate))
#
# Cell In[1], line 25, in move_left(state, pos)
#      24 def move_left(state, pos):
# ---> 25     if pos[1] == 0:
#      26         return None
#      27     retarr = copy.deepcopy(state)
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# ######
